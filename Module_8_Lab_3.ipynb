# %% [markdown]
# <a href="https://colab.research.google.com/github/Bharu0326/FMML-LAB1/blob/main/Module_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-16 11:35:27--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   102MB/s    in 0.7s
#
# 2024-04-16 11:35:30 (102 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 5431    1210.4856v1  The recent proliferation of richly structured ...    cs
# 10400   1306.2035v1  While several papers have investigated computa...  stat
# 34875   1110.2074v1  In our work we propose implementing fuzzy logi...    cs
# 22092   1411.0439v1  We propose a novel sampling framework for infe...  stat
# 5671   1604.06498v3  Stochastic gradient descent (SGD) is commonly ...  stat
# ...             ...                                                ...   ...
# 32780  1506.07300v2  The computational cost of many signal processi...    cs
# 6053   1606.05798v1  As a contribution to interpretable machine lea...  stat
# 6813   1706.04161v1  The Gumbel trick is a method to sample from a ...  stat
# 3332   1510.01628v1  The nowadays massive amounts of generated and ...    cs
# 28389  1706.04318v1  Describing the color and textural information ...    cs
#
#                                                    title  year  \
# 5431   Exploiting compositionality to explore a large...  2012
# 10400  Minimax Theory for High-dimensional Gaussian M...  2013
# 34875               Memristors can implement fuzzy logic  2011
# 22092  Sampling for Inference in Probabilistic Models...  2014
# 5671   Stabilized Sparse Online Learning for Sparse Data  2016
# ...                                                  ...   ...
# 32780  Flexible Multi-layer Sparse Approximations of ...  2015
# 6053   Interpretable Two-level Boolean Rule Learning ...  2016
# 6813                  Lost Relatives of the Gumbel Trick  2017
# 3332   Large-scale subspace clustering using sketchin...  2015
# 28389  Hierarchical Gaussian Descriptors with Applica...  2017
#
#                                                 keywords
# 5431   [proliferation, structured, probabilistic, aut...
# 10400  [investigated, computationally, statistically,...
# 34875  [implementing, memristors, operations, antipod...
# 22092  [framework, inference, probabilistic, converge...
# 5671   [stochastic, optimization, introduce, truncate...
# ...                                                  ...
# 32780  [computational, processing, techniques, domina...
# 6053   [contribution, interpretable, optimization, fr...
# 6813   [probability, distribution, normalizing, parti...
# 3332   [generated, communicated, challenges, processi...
# 28389  [describing, information, identification, desc...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 5431     [proliferation, structured, probabilistic, aut...
# 10400    [investigated, computationally, statistically,...
# 34875    [implementing, memristors, operations, antipod...
# 22092    [framework, inference, probabilistic, converge...
# 5671     [stochastic, optimization, introduce, truncate...
#                                ...
# 4932     [nontrivial, involving, carefully, selecting, ...
# 24686    [detection, applications, important, applicati...
# 32763    [algorithm, experiments, suggested, algorithm,...
# 30154    [significant, articulated, manipulators, appro...
# 22827    [anomalous, resulting, information, anomalies,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8796 words.
# Out of those 4552 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="014eb607-0365-4245-bb14-8b1a71b098a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("014eb607-0365-4245-bb14-8b1a71b098a3")) {                    Plotly.newPlot(                        "014eb607-0365-4245-bb14-8b1a71b098a3",                        [{"x":["predictive","structured","gracefully","generically","appropriate","components","evaluating","automatically","proliferation","unsupervised","probabilistic","generates","typically","efficiently","determine","application","algorithms","likelihood","compositional","synthetic","selection","decomposition","investigate","questions","compositionality","structures","structure","exploiting","statistically","theoretic","theoretical","computationally","information","efficient","dimensions","statistical","investigated","isotropic","procedure","complexity","performance","dimensional","separation","gaussians","understood","fundamental","clustering","configured","classifiers","implement","computational","presented","memristors","experimentally","operations","memristor","memristive","implementing","implemented","applicable","efficiency","assembled","integration","partition","numerical","quadrature","computation","inference","demonstrated","importance","techniques","framework","locations","diagnostics","challenge","algorithm","convergence","ensembles","inefficiency","approaches","converges","benchmarks","introduce","permitting","prohibitive","integrands","optimally","exploration","stabilized","prediction","thresholding","experiments","variability","controlled","truncated","optimization","facilitate","heterogeneity","shrinkage","integrated","stochastic","informative","exploitation","stability","truncation","available","favorably","annealing","different","segmented","segmentation","parameters","furthermore","demonstrate","modalities","microsoft","representative","experimental","sequences","representation","repetition","frequency","unscented","detection","kinematic","repetitive","iterative","determining","universal","important","minimizing","partitions","generally","improving","partitioning","solutions","reasonable","converging","iteration","regardless","extraction","introduces","decompositions","substantial","represented","orthogonal","significantly","optimizing","underlying","classification","multidimensional","extracting","recursive","successive","benchmark","achieving","indicated","displacement","supported","randomized","structural","conducted","considered","reduction","undamaged","existence","propagation","estimating","identification","recognize","behaviour","parameter","anisotropic","guarantees","empirical","magnitude","preserving","favorable","predicting","correlation","particular","observation","addressing","analytically","monitoring","principled","uncertainty","conditions","evaluation","occurring","phenomena","environmental","increasing","phenomenon","incurring","consequence","practical","distribution","currently","intelligent"],"y":[56,108,1,3,73,103,52,177,4,125,174,57,94,152,45,248,579,62,26,139,178,68,147,51,10,132,329,84,18,39,139,86,692,399,45,150,50,4,110,229,909,190,28,8,21,89,154,3,125,69,297,180,3,46,77,2,2,20,98,53,158,3,49,36,76,0,135,213,103,82,395,531,35,6,164,796,131,7,5,441,15,107,354,1,8,0,23,64,0,233,17,565,28,39,6,315,32,8,5,45,142,37,17,20,3,309,14,14,743,21,208,227,149,545,40,6,38,378,108,350,4,59,2,317,5,6,55,39,39,380,42,13,73,130,18,155,32,8,40,17,133,72,13,45,85,21,287,35,121,523,10,56,22,13,196,93,4,12,21,17,59,73,114,100,2,25,69,56,105,41,27,103,9,58,155,61,37,7,73,70,278,48,28,13,40,25,84,132,265,16,31,22,108,22,5,22,136,210,48,65],"type":"bar"},{"x":["predictive","structured","gracefully","generically","appropriate","components","evaluating","automat ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4552,), (4552, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8066666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Modeling</span> <span style=''>Dynamic</span> <span style=''>Swarms</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>proposes</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>modeling</span> <span style=''>video</span> <span style='background-color:rgba(0, 255, 0, 0.48965517241379314);'>sequences</span> <span style=''>of</span> <span style=''>dynamic</span> <span style=''>swarms</span> <span style=''>(DS)</span> <span style=''>We</span> <span style=''>define</span> <span style=''>DS</span> <span style=''>as</span> <span style=''>a</span> <span style=''>large</span> <span style=''>layout</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>stochastically</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>repetitive</span> <span style=''>spatial</span> <span style='background-color:rgba(0, 255, 0, 0.35);'>configurations</span> <span style=''>of</span> <span style=''>dynamic</span> <span style=''>objects</span> <span style=''>(swarm</span> <span style=''>elements)</span> <span style=''>whose</span> <span style=''>motions</span> <span style=''>exhibit</span> <span style=''>local</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>spatiotemporal</span> <span style=''>interdependency</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.5);'>stationarity</span> <span style=''>ie</span> <span style=''>the</span> <span style=''>motions</span> <span style=''>are</span> <span style=''>similar</span> <span style=''>in</span> <span style=''>any</span> <span style=''>small</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>spatiotemporal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>neighborhood</span> <span style=''>Examples</span> <span style=''>of</span> <span style=''>DS</span> <span style=''>abound</span> <span style=''>in</span> <span style=''>nature</span> <span style=''>eg</span> <span style=''>herds</span> <span style=''>of</span> <span style=''>animals</span> <span style=''>and</span> <span style=''>flocks</span> <span style=''>of</span> <span style=''>birds</span> <span style=''>To</span> <span style=''>capture</span> <span style=''>the</span> <span style=''>local</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>spatiotemporal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>the</span> <span style=''>DS</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style=''>model</span> <span style=''>that</span> <span style=''>learns</span> <span style=''>both</span> <span style=''>the</span> <span style=''>spatial</span> <span style=''>layout</span> <span style=''>of</span> <span style=''>swarm</span> <span style=''>elements</span> <span style=''>and</span> <span style=''>their</span> <span style=''>joint</span> <span style=''>dynamics</span> <span style=''>that</span> <span style=''>are</span> <span style=''>modeled</span> <span style=''>as</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transformations</span> <span style=''>To</span> <span style=''>this</span> <span style=''>end</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>spatiotemporal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>neighborhood</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>associated</span> <span style=''>with</span> <span style=''>each</span> <span style=''>swarm</span> <span style=''>element</span> <span style=''>in</span> <span style=''>which</span> <span style=''>local</span> <span style='background-color:rgba(255, 0, 0, 0.5);'>stationarity</span> <span style=''>is</span> <span style=''>enforced</span> <span style=''>both</span> <span style= ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Biologically</span> <span style=''>inspired</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>protection</span> <span style=''>of</span> <span style=''>deep</span> <span style=''>networks</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversarial</span> <span style=''>attacks</span> <br/><br/><span style=''>Inspired</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>biophysical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>principles</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dendritic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style=''>in</span> <span style=''>neural</span> <span style=''>circuits</span> <span style=''>we</span> <span style=''>develop</span> <span style=''>a</span> <span style=''>scheme</span> <span style=''>to</span> <span style=''>train</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>to</span> <span style=''>make</span> <span style=''>them</span> <span style=''>robust</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversarial</span> <span style=''>attacks</span> <span style=''>Our</span> <span style=''>scheme</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generates</span> <span style=''>highly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>saturated</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>that</span> <span style=''>achieve</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>on</span> <span style=''>gradient</span> <span style=''>based</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversarial</span> <span style=''>examples</span> <span style=''>on</span> <span style=''>MNIST</span> <span style=''>despite</span> <span style=''>never</span> <span style=''>being</span> <span style=''>exposed</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adversarially</span> <span style=''>chosen</span> <span style=''>examples</span> <span style=''>during</span> <span style=''>training</span> <span style=''>Moreover</span> <span style=''>these</span> <span style=''>networks</span> <span style=''>exhibit</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unprecedented</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>robustness</span> <span style=''>to</span> <span style=''>targeted</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iterative</span> <span style=''>schemes</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generating</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>adversarial</span> <span style=''>examples</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style=''>second</span> <span style=''>order</span> <span style=''>methods</span> <span style=''>We</span> <span style=''>further</span> <span style=''>identify</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>principles</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>governing</span> <span style=''>how</span> <span style=''>these</span> <span style=''>networks</span> <span style=''>achieve</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>robustness</span> <span style=''>drawing</span> <span style=''>on</span> <span style=''>methods</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inform ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>The</span> <span style=''>Physical</span> <span style=''>Systems</span> <span style=''>Behind</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithms</span> <br/><br/><span style=''>We</span> <span style=''>use</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>differential</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>equations</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>to</span> <span style=''>provide</span> <span style=''>some</span> <span style=''>it</span> <span style=''>textbfphysics</span> <span style=''>insights</span> <span style=''>into</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>analyzing</span> <span style=''>the</span> <span style=''>dynamics</span> <span style=''>of</span> <span style=''>popular</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>study</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>proximal</span> <span style=''>gradient</span> <span style=''>descent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coordinate</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>proximal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>coordinate</span> <span style=''>gradient</span> <span style=''>and</span> <span style=''>Newtons</span> <span style=''>methods</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>their</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Nesterovs</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>accelerated</span> <span style=''>variants</span> <span style=''>in</span> <span style=''>a</span> <span style=''>unified</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>motivated</span> <span style=''>by</span> <span style=''>a</span> <span style=''>natural</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>connection</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>to</span> <span style=''>physical</span> <span style=''>systems</span> <span style=''>Our</span> <span style=''>analysis</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applicable</span> <span style=''>to</span> <span style=''>more</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problems</span> <span style=''>it</span> <span style=''>textbfbeyond</span> <span style='background-color:rgba(255, 0, 0, 0.5555555555555556);'>convexity</span> <span style=''>and</span> <span style=''>strong</span> <span style='background-color:rgba(255, 0, 0, 0.5555555555555556);'>convexity</span> <span style=''>eg</span> <span style=''>Polyak</span> <span style=''>L</span> <span style=''>ojasiewicz</span> <span style=''>and</span> <span style=''>error</span> <span style=''>bound</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>(possibly</span> <span style=''>nonconvex)</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Resizable</span> <span style=''>Mini</span> <span style=''>batch</span> <span style=''>Gradient</span> <span style=''>Descent</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>Multi</span> <span style=''>Armed</span> <span style=''>Bandit</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Determining</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>appropriate</span> <span style=''>batch</span> <span style=''>size</span> <span style=''>for</span> <span style=''>mini</span> <span style=''>batch</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>is</span> <span style=''>always</span> <span style=''>time</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consuming</span> <span style=''>as</span> <span style=''>it</span> <span style=''>often</span> <span style=''>relies</span> <span style=''>on</span> <span style=''>grid</span> <span style=''>search</span> <span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>considers</span> <span style=''>a</span> <span style=''>resizable</span> <span style=''>mini</span> <span style=''>batch</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>(RMGD)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style=''>multi</span> <span style=''>armed</span> <span style=''>bandit</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>achieving</span> <span style=''>best</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>in</span> <span style=''>grid</span> <span style=''>search</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selecting</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>appropriate</span> <span style=''>batch</span> <span style=''>size</span> <span style=''>at</span> <span style=''>each</span> <span style=''>epoch</span> <span style=''>with</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style=''>defined</span> <span style=''>as</span> <span style=''>a</span> <span style=''>function</span> <span style=''>of</span> <span style=''>its</span> <span style=''>previous</span> <span style=''>successfailure</span> <span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>encourages</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exploration</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>batch</span> <span style=''>size</span> <span style=''>and</span> <span style=''>then</span> <span style=''>later</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploitation</span> <span style=''>of</span> <span style=''>batch</span> <span style=''>size</span> <span style=''>with</span> <span style=''>history</span> <span style=''>of</span> <span style=''>success</span> <span style=''>At</span> <span style=''>each</span> <span style=''>epoch</span> <span style=''>the</span> <span style=''>RMGD</span> <span style=''>samples</span> <span style=''>a</span> <span style=''>batch</span> <span style=''>size</span> <span style=''>from</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>then</span> <span style=''>uses</span> <span style=''>the</span> <span style=''>selected</span> <span style=''>batch</span> <span style=''>size</span> <span style=''>for</span> <span style=''>mini</span> <span style=''>batch</span> <span style= ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.12544802867383512)
# 	representation (0.12544802867383512)
# 	architecture (0.08566308243727598)
# 	processing (0.1086021505376344)
# 	information (0.24802867383512545)
# 	detection (0.11362007168458782)
# 	segmentation (0.07455197132616488)
# 	different (0.2663082437275986)
# 	recognition (0.13835125448028673)
# 	convolutional (0.13727598566308244)
#
# Some Statistics words are:
# 	parameter (0.1253731343283582)
# 	theoretical (0.1417910447761194)
# 	variables (0.13781094527363183)
# 	estimation (0.1746268656716418)
# 	statistical (0.16119402985074627)
# 	algorithm (0.3945273631840796)
# 	inference (0.191044776119403)
# 	distribution (0.1925373134328358)
# 	dimensional (0.19601990049751244)
# 	regression (0.1736318407960199)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="727c2acc-7dc8-46d6-a3c7-7840513bc49a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("727c2acc-7dc8-46d6-a3c7-7840513bc49a")) {                    Plotly.newPlot(                        "727c2acc-7dc8-46d6-a3c7-7840513bc49a",                        [{"x":["predictive","structured","gracefully","generically","appropriate","components","evaluating","automatically","proliferation","unsupervised","probabilistic","generates","typically","efficiently","determine","application","algorithms","likelihood","compositional","synthetic","selection","decomposition","investigate","questions","compositionality","structures","structure","exploiting","statistically","theoretic","theoretical","computationally","information","efficient","dimensions","statistical","investigated","isotropic","procedure","complexity","performance","dimensional","separation","gaussians","understood","fundamental","clustering","configured","classifiers","implement","computational","presented","memristors","experimentally","operations","memristor","memristive","implementing","implemented","applicable","efficiency","assembled","integration","partition","numerical","quadrature","computation","inference","demonstrated","importance","techniques","framework","locations","diagnostics","challenge","algorithm","convergence","ensembles","inefficiency","approaches","converges","benchmarks","introduce","permitting","prohibitive","integrands","optimally","exploration","stabilized","prediction","thresholding","experiments","variability","controlled","truncated","optimization","facilitate","heterogeneity","shrinkage","integrated","stochastic","informative","exploitation","stability","truncation","available","favorably","annealing","different","segmented","segmentation","parameters","furthermore","demonstrate","modalities","microsoft","representative","experimental","sequences","representation","repetition","frequency","unscented","detection","kinematic","repetitive","iterative","determining","universal","important","minimizing","partitions","generally","improving","partitioning","solutions","reasonable","converging","iteration","regardless","extraction","introduces","decompositions","substantial","represented","orthogonal","significantly","optimizing","underlying","classification","multidimensional","extracting","recursive","successive","benchmark","achieving","indicated","displacement","supported","randomized","structural","conducted","considered","reduction","undamaged","existence","propagation","estimating","identification","recognize","behaviour","parameter","anisotropic","guarantees","empirical","magnitude","preserving","favorable","predicting","correlation","particular","observation","addressing","analytically","monitoring","principled","uncertainty","conditions","evaluation","occurring","phenomena","environmental","increasing","phenomenon","incurring","consequence","practical","distribution","currently","intelligent","modifications","stationary","evolutionary","necessity","dimension","assumption","inconsistent","strategies","necessary","summaries","occurrence","analyzing","distinguish","visualizing","electroencephalography","convolutional","engineered","individual","knowledge","comparable","validation","automatic","correspond","continuous","bernoulli","posterior","improvement","considering","retrieval","approximate","descriptors","approximation","probability","accelerating","attention","significant","attracted","effectiveness","classifier","precision","statistics","distributions","posteriors","functions","multivariate","transfers","simultaneously","densities","transferability","understanding","adaptation","synthesise","evolution","especially","environment","programmin ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	quadrature
# 	integrands
# 	stabilized
# 	subsamples
# 	reflectivity
# 	spectroradiometer
# 	divisible
# 	amortization
# 	extrapolate
# 	resampled
# 	graphically
# 	distinguishable
# 	dendrogram
# 	horizontally
# 	initialise
# 	amortised
# 	asymptotics
# 	reinterpret
# 	reparametrizations
# 	imaginary
# Some words which never appear in Statistics papers:
# 	configured
# 	memristors
# 	memristor
# 	memristive
# 	assembled
# 	repetition
# 	repetitive
# 	displacement
# 	undamaged
# 	behavioural
# 	discounting
# 	connectionist
# 	utterance
# 	recognizer
# 	symbolically
# 	taxonomies
# 	scholarly
# 	disturbances
# 	multimedia
# 	halfspace

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.081474177246395e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7766666666666666
